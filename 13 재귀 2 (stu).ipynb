# %% [markdown]
# # 1~n까지의 합

# %% [raw]
# 점화식 : 재귀식, 항 사이에 성립하는 관계식
# 점화식 : f(n) = f(n-1) + 1
# base condition : n = 1 일 때, f(1) = 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(x) :
    if x == 1 : return 1  #종료 조건
    return f(x-1) + x

n = int(input())
res = f(n)
print(res)
# Out:
# 3
# 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1855 : [기초-재귀함수] 재귀로 n번째 피보나치 수 리턴하기

# %% [raw]
# [관련 문제-1] 2601 : 피보나치 수열

# %% [markdown]
# # 1851 : [기초-재귀함수] 재귀로 * n개 한 줄로 출력하기

# %% [raw]
# [관련 문제-1] 1901 : (재귀 함수) 1부터 n까지 출력하기
# [관련 문제-2] 1256 : 별 출력하기

# %% [markdown]
# # 1854 : [기초-재귀함수] 재귀로 각 자리 수의 합 리턴하기

# %% [raw]
# [관련 문제 - 1] 1853 : [기초-재귀함수] 재귀로 1부터 n까지 합 리턴하기
# [관련 문제 - 2] 1620 : 자릿수의 합

# %% [markdown]
# # 1919 : (재귀 함수) 숫자 거꾸로 출력하기

# %% [raw]
# [관련 문제 - 1] 1920 : (재귀함수) 2진수 변환
# [관련 문제 - 2] 1714 : 숫자 거꾸로 출력하기

# %% [markdown]
# # 1922 : [재귀함수] 3n+1

# %%
[관련 문제 - 1] 우박수 길이 (3n+1) (small)

# %% [markdown]
# # 1928 : (재귀함수) 우박수 (3n+1) (basic)

# %% [markdown]
# # 1929 : (재귀함수) 우박수 (3n+1) (reverse)

# %% [markdown]
# # 2632 : 계단 오르기 1

# %% [raw]
# [관련 문제 - 1] 1915 : (재귀함수) 피보나치 수열

# %% [markdown]
# # 1856 : [기초-재귀함수] 계단 뛰어 오르기
